# %%
import numpy as np

# %%
import pandas as pd

# %%
data=pd.read_csv("car.csv")

# %%
data
# Out:
#       ID  symboling                      name fueltypes aspiration  \
# 0      1          3        alfa-romero giulia       gas        std
# 1      2          3       alfa-romero stelvio       gas        std
# 2      3          1  alfa-romero Quadrifoglio       gas        std
# 3      4          2               audi 100 ls       gas        std
# 4      5          2                audi 100ls       gas        std
# ..   ...        ...                       ...       ...        ...
# 200  201         -1           volvo 145e (sw)       gas        std
# 201  202         -1               volvo 144ea       gas      turbo
# 202  203         -1               volvo 244dl       gas        std
# 203  204         -1                 volvo 246    diesel      turbo
# 204  205         -1               volvo 264gl       gas      turbo
#
#     doornumbers      carbody drivewheels enginelocation  wheelbase  ...  \
# 0           two  convertible         rwd          front       88.6  ...
# ...

# %%
data.head()
# Out:
#    ID  symboling                      name fueltypes aspiration doornumbers  \
# 0   1          3        alfa-romero giulia       gas        std         two
# 1   2          3       alfa-romero stelvio       gas        std         two
# 2   3          1  alfa-romero Quadrifoglio       gas        std         two
# 3   4          2               audi 100 ls       gas        std        four
# 4   5          2                audi 100ls       gas        std        four
#
#        carbody drivewheels enginelocation  wheelbase  ...  enginesize  \
# 0  convertible         rwd          front       88.6  ...         130
# 1  convertible         rwd          front       88.6  ...         130
# 2    hatchback         rwd          front       94.5  ...         152
# 3        sedan         fwd          front       99.8  ...         109
# 4        sedan         4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
data.tail()
# Out:
#       ID  symboling             name fueltypes aspiration doornumbers carbody  \
# 200  201         -1  volvo 145e (sw)       gas        std        four   sedan
# 201  202         -1      volvo 144ea       gas      turbo        four   sedan
# 202  203         -1      volvo 244dl       gas        std        four   sedan
# 203  204         -1        volvo 246    diesel      turbo        four   sedan
# 204  205         -1      volvo 264gl       gas      turbo        four   sedan
#
#     drivewheels enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200         rwd          front      109.1  ...         141        mpfi
# 201         rwd          front      109.1  ...         141        mpfi
# 202         rwd          front      109.1  ...         173        mpfi
# 203         rwd          front      109.1  ...         145         idi
# 204         rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
data.isnull()
# Out:
#         ID  symboling   name  fueltypes  aspiration  doornumbers  carbody  \
# 0    False      False  False      False       False        False    False
# 1    False      False  False      False       False        False    False
# 2    False      False  False      False       False        False    False
# 3    False      False  False      False       False        False    False
# 4    False      False  False      False       False        False    False
# ..     ...        ...    ...        ...         ...          ...      ...
# 200  False      False  False      False       False        False    False
# 201  False      False  False      False       False        False    False
# 202  False      False  False      False       False        False    False
# 203  False      False  False      False       False        False    False
# 204  False      False  False      False       False        False    False
#
#      drivewheels  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# ...

# %%
data.isnull().sum()
# Out:
# ID                  0
# symboling           0
# name                0
# fueltypes           0
# aspiration          0
# doornumbers         0
# carbody             0
# drivewheels         0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
data.notnull()
# Out:
#        ID  symboling  name  fueltypes  aspiration  doornumbers  carbody  \
# 0    True       True  True       True        True         True     True
# 1    True       True  True       True        True         True     True
# 2    True       True  True       True        True         True     True
# 3    True       True  True       True        True         True     True
# 4    True       True  True       True        True         True     True
# ..    ...        ...   ...        ...         ...          ...      ...
# 200  True       True  True       True        True         True     True
# 201  True       True  True       True        True         True     True
# 202  True       True  True       True        True         True     True
# 203  True       True  True       True        True         True     True
# 204  True       True  True       True        True         True     True
#
#      drivewheels  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# ...

# %%
data.notnull().sum()
# Out:
# ID                  205
# symboling           205
# name                205
# fueltypes           205
# aspiration          205
# doornumbers         205
# carbody             205
# drivewheels         205
# enginelocation      205
# wheelbase           205
# carlength           205
# carwidth            205
# carheight           205
# curbweight          205
# enginetype          205
# cylindernumber      205
# enginesize          205
# fuelsystem          205
# boreratio           205
# stroke              205
# compressionratio    205
# horsepower          205
# peakrpm             205
# citympg             205
# highwaympg          205
# price               205
# dtype: int64

# %%
data.columns
# Out:
# Index(['ID', 'symboling', 'name', 'fueltypes', 'aspiration', 'doornumbers',
#        'carbody', 'drivewheels', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
data.rename(columns={"ID":"Identity"})
# Out:
#      Identity  symboling                      name fueltypes aspiration  \
# 0           1          3        alfa-romero giulia       gas        std
# 1           2          3       alfa-romero stelvio       gas        std
# 2           3          1  alfa-romero Quadrifoglio       gas        std
# 3           4          2               audi 100 ls       gas        std
# 4           5          2                audi 100ls       gas        std
# ..        ...        ...                       ...       ...        ...
# 200       201         -1           volvo 145e (sw)       gas        std
# 201       202         -1               volvo 144ea       gas      turbo
# 202       203         -1               volvo 244dl       gas        std
# 203       204         -1                 volvo 246    diesel      turbo
# 204       205         -1               volvo 264gl       gas      turbo
#
#     doornumbers      carbody drivewheels enginelocation  wheelbase  ...  \
# ...

# %%
data.columns
# Out:
# Index(['ID', 'symboling', 'name', 'fueltypes', 'aspiration', 'doornumbers',
#        'carbody', 'drivewheels', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
data.rename(columns={"symboling":"Symboling", "name":"Name","fueltypes":"Fuel_Types","aspiration":"Aspiration","doornumbers":"Door_Numbers","carbody":"Car_Body","drivewheels":"Drive_Wheels","enginelocation":"Engine_Location","wheelbase":"Wheel_Base","carlength":"Car_Length","carwidth":"Car_Width","carheight":"Car_Height","curbweight":"Curb_Weight","enginetype":"Engine_Type","cylindernumber":"Cylinder_Number","enginesize":"Engine_Size","fuelsystem":"Fuel_System","boreratio":"Bore_Ratio","compressionratio":"Compression_Ratio","horsepower":"Horse_Power","peakrpm":"Peak_rpm","citympg":"City_mpg","highwaympg":"Highway_mpg"},inplace=True)

# %%
data.rename(columns={"price":"Price"})
# Out:
#       ID  Symboling                      Name Fuel_Types Aspiration  \
# 0      1          3        alfa-romero giulia        gas        std
# 1      2          3       alfa-romero stelvio        gas        std
# 2      3          1  alfa-romero Quadrifoglio        gas        std
# 3      4          2               audi 100 ls        gas        std
# 4      5          2                audi 100ls        gas        std
# ..   ...        ...                       ...        ...        ...
# 200  201         -1           volvo 145e (sw)        gas        std
# 201  202         -1               volvo 144ea        gas      turbo
# 202  203         -1               volvo 244dl        gas        std
# 203  204         -1                 volvo 246     diesel      turbo
# 204  205         -1               volvo 264gl        gas      turbo
#
#     Door_Numbers     Car_Body Drive_Wheels Engine_Location  Wheel_Base  ...  \
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Symboling', 'Name', 'Fuel_Types', 'Aspiration', 'Door_Numbers',
#        'Car_Body', 'Drive_Wheels', 'Engine_Location', 'Wheel_Base',
#        'Car_Length', 'Car_Width', 'Car_Height', 'Curb_Weight', 'Engine_Type',
#        'Cylinder_Number', 'Engine_Size', 'Fuel_System', 'Bore_Ratio', 'stroke',
#        'Compression_Ratio', 'Horse_Power', 'Peak_rpm', 'City_mpg',
#        'Highway_mpg', 'price'],
#       dtype='object')

# %%
new_df=data[["Engine_Size","price"]]

# %%
new_df
# Out:
#      Engine_Size    price
# 0            130  13495.0
# 1            130  16500.0
# 2            152  16500.0
# 3            109  13950.0
# 4            136  17450.0
# ..           ...      ...
# 200          141  16845.0
# 201          141  19045.0
# 202          173  21485.0
# 203          145  22470.0
# 204          141  22625.0
#
# [205 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(new_df['Engine_Size'],new_df['price'])
plt.xlabel("Engine_Size")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %%
x=new_df.iloc[ :, 0:1]

# %%
y=new_df.iloc[ :, -1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#      Engine_Size
# 25            90
# 84           156
# 100          120
# 10           108
# 195          141
# 53            91
# 65           140
# 66           134
# 182           97
# 175          122
# 29           156
# 153           92
# 183          109
# 13           164
# 134          121
# 94            97
# 164           98
# 35            92
# 127          194
# 24            90
# 23            98
# 45            90
# 6            136
# 12           164
# 64           122
# 18            61
# 157           98
# 173          122
# 172          146
# 2            152
# 57            70
# 3            109
# 120           90
# 14           164
# 44            90
# 178          171
# 113          120
# 179          171
# 192           97
# 184           97
# 111          120

# %%
y_test
# Out:
# 25      6692.0
# 84     14489.0
# 100     9549.0
# 10     16430.0
# 195    13415.0
# 53      6695.0
# 65     18280.0
# 66     18344.0
# 182     7775.0
# 175     9988.0
# 29     12964.0
# 153     6918.0
# 183     7975.0
# 13     21105.0
# 134    15040.0
# 94      7299.0
# 164     8238.0
# 35      7295.0
# 127    34028.0
# 24      6229.0
# 23      7957.0
# 45      8916.5
# 6      17710.0
# 12     20970.0
# 64     11245.0
# 18      5151.0
# 157     7198.0
# 173     8948.0
# 172    17669.0
# 2      16500.0
# 57     13645.0
# 3      13950.0
# 120     6229.0
# 14     24565.0
# 44      8916.5
# 178    16558.0
# 113    16695.0
# 179    15998.0
# 192    13845.0
# 184     7995.0
# 111    15580.0
# Name: price, dtype: float64

# %%
lr.predict(x_test.iloc[3].values.reshape(1,1))
# Out:
# array([9867.26797698])

# %%
plt.scatter(new_df["Engine_Size"],new_df["price"])
plt.plot(x_train,lr.predict(x_train),color='red')
plt.xlabel('enginesize')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
m=lr.coef_

# %%
m
# Out:
# array([169.94850728])

# %%
b=lr.intercept_

# %%
b
# Out:
# -8487.170809082498
